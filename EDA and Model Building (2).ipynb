# %%
import os
os.chdir(r"C:\Users\USER\Desktop\New folder\DSP_Capstone Project\Python Project")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
clean_my_data=pd.read_csv("Cleaneddata_final.csv")

# %%
clean_my_data.head()
# Out:
#    loan_amnt  term  int_rate  installment  grade  emp_length  home_ownership  \
# 0     5000.0     1     10.65       162.87      1        10.0               5
# 1     2500.0     0     15.27        59.83      2         0.0               5
# 2     2400.0     1     15.96        84.33      2        10.0               5
# 3    10000.0     1     13.49       339.31      2        10.0               5
# 4     3000.0     0     12.69        67.79      1         1.0               5
#
#    annual_inc  verification_status     issue_d  ...  recoveries  \
# 0     24000.0                    2  2011-12-01  ...        0.00
# 1     30000.0                    1  2011-12-01  ...      117.08
# 2     12252.0                    0  2011-12-01  ...        0.00
# 3     49200.0                    1  2011-12-01  ...        0.00
# 4     80000.0                    1  2011-12-01  ...        0.00
#
#    collection_recovery_fee  last_pymnt_amnt  collections_12_mths_ex_med  \
# ...

# %%
clean_my_data.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'purpose', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'total_pymnt', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt',
#        'collections_12_mths_ex_med', 'application_type', 'acc_now_delinq',
#        'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'default_ind'],
#       dtype='object')

# %%
clean_my_data.describe().T
# Out:
#                                count           mean            std     min  \
# loan_amnt                   855969.0   14745.571335    8425.340005  500.00
# term                        855969.0       0.701218       0.457724    0.00
# int_rate                    855969.0      13.192320       4.368365    5.32
# installment                 855969.0     436.238072     243.726876   15.69
# grade                       855969.0       1.777849       1.304639    0.00
# emp_length                  855969.0       6.219589       3.674739    0.00
# home_ownership              855969.0       2.895954       1.921844    0.00
# annual_inc                  855969.0   75071.185963   64264.469813    0.00
# verification_status         855969.0       1.026061       0.792215    0.00
# purpose                     855969.0       2.562310       2.271336    0.00
# dti                         855969.0      18.122165      17.423629    0.00
# ...

# %%
clean_my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855969 entries, 0 to 855968
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   855969 non-null  float64
#  1   term                        855969 non-null  int64
#  2   int_rate                    855969 non-null  float64
#  3   installment                 855969 non-null  float64
#  4   grade                       855969 non-null  int64
#  5   emp_length                  855969 non-null  float64
#  6   home_ownership              855969 non-null  int64
#  7   annual_inc                  855969 non-null  float64
#  8   verification_status         855969 non-null  int64
#  9   issue_d                     855969 non-null  object
#  10  purpose                     855969 non-null  int64
#  11  dti                         855969 non-null  float64
# ...

# %%
clean_my_data.shape
# Out:
# (855969, 35)

# %%
col_data=clean_my_data.iloc[:,0:20].columns

# %%
col_data_1=clean_my_data.iloc[:,20:].columns

# %%
col_data
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'issue_d',
#        'purpose', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status'],
#       dtype='object')

# %%
colur_data=["c","gray","purple","hotpink","dodgerblue",
            "lightgreen","orange","skyblue","slategray","maroon",
            "olive","darkcyan","lightcoral",
            "palegreen","sandybrown","red","dimgrey","seagreen","rosybrown",
            "lime","gray"]

# %%
values=range(1,21)

# %%
plt.figure(figsize=(11,11), facecolor='white')
plt.style.use('ggplot')

for i,j,k in zip(col_data,colur_data,values):
        ax = plt.subplot(5,4,k)
        plt.hist(clean_my_data[i],facecolor=j)
        plt.xlabel(i)
plt.tight_layout()

# %%
values_1=range(1,25)

# %%
plt.figure(figsize=(13,13), facecolor='white')
plt.style.use('ggplot')

for i,j,k in zip(col_data_1,colur_data,values_1):
        ax = plt.subplot(5,5,k)
        plt.hist(clean_my_data[i],facecolor=j)
        plt.xlabel(i)
plt.tight_layout()

# %%
plt.figure(figsize=(25,25)) 
sns.heatmap(clean_my_data.corr(), annot=True,cmap ='RdYlGn')

# %%
plt.figure(figsize=(15,15)) 
plt.style.use('ggplot')
sns.boxplot(data = clean_my_data,width=.8,orient="h")

# %%
clean_my_data["int_rate"] = np.where(clean_my_data["int_rate"] >24.99,24.99,clean_my_data["int_rate"])
clean_my_data["installment"] = np.where(clean_my_data["installment"] >1038.06,1038.06,clean_my_data["installment"])
clean_my_data["annual_inc"] = np.where(clean_my_data["annual_inc"] >157500,157500,clean_my_data["annual_inc"])
clean_my_data["dti"] = np.where(clean_my_data["dti"] >41.93,41.93,clean_my_data["dti"])
clean_my_data["revol_bal"] = np.where(clean_my_data["revol_bal"] >42439,42439,clean_my_data["revol_bal"])
clean_my_data["tot_cur_bal"] = np.where(clean_my_data["tot_cur_bal"] >442557.5,442557.5,clean_my_data["tot_cur_bal"])
clean_my_data["total_rev_hi_lim"] = np.where(clean_my_data["total_rev_hi_lim"] >72875.0,72875.0,clean_my_data["total_rev_hi_lim"])

# %%
plt.figure(figsize=(15,15)) 
plt.style.use('ggplot')
sns.boxplot(data = clean_my_data,width=.8,orient="h")

# %%
clean_my_data.shape
# Out:
# (855969, 35)

# %% [markdown]
# # DOWN SAMPLING

# %%
clean_my_data["default_ind"].value_counts()
# Out:
# 0    809502
# 1     46467
# Name: default_ind, dtype: int64

# %%
height = [809502,46467]
bars = ('0','1')
plt.bar(bars, height,color=("green","red"))
plt.xlabel("count")
plt.ylabel("Default_Payment")
# Out:
# Text(0, 0.5, 'Default_Payment')

# %%
from sklearn.utils import resample

# %%
df_majority=clean_my_data[clean_my_data.default_ind==0]
df_minority=clean_my_data[clean_my_data.default_ind==1]

# %%
df_majority_downsampled=resample(df_majority,replace=True,n_samples=46467,random_state=123)
my_data_downsampled=pd.concat([df_majority_downsampled,df_minority])

# %%
my_data_downsampled.shape
# Out:
# (92934, 35)

# %%
my_data_downsampled["default_ind"].value_counts()
# Out:
# 1    46467
# 0    46467
# Name: default_ind, dtype: int64

# %%
height = [46467,46467]
bars = ('0','1')
plt.bar(bars, height,color=("pink","grey"))
plt.xlabel("count")
plt.ylabel("Default_Payment")
# Out:
# Text(0, 0.5, 'Default_Payment')

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
train_data=my_data_downsampled[my_data_downsampled["issue_d"]<"2015-06-01"]

# %%
# train_data=clean_my_data[clean_my_data["issue_d"]<"2015-06-01"]

# %%
train_data.shape
# Out:
# (77937, 35)

# %%
test_data=my_data_downsampled[my_data_downsampled["issue_d"]>="2015-06-01"]

# %%
#test_data.shape

# %%
# test_data=clean_my_data[clean_my_data["issue_d"]>="2015-06-01"]

# %%
X_train=train_data.drop(["default_ind","issue_d"],axis=1)

# %%
X_train.shape
# Out:
# (77937, 33)

# %%
Y_train=train_data["default_ind"]

# %%
X_test=test_data.drop(["default_ind","issue_d"],axis=1)
X_test.shape
# Out:
# (14997, 33)

# %%
Y_test=test_data["default_ind"]

# %%
from sklearn.tree import ExtraTreeClassifier
selection=ExtraTreeClassifier()

# %%
selection.fit(X_train,Y_train)
# Out:
# ExtraTreeClassifier()

# %%
selection.feature_importances_
# Out:
# array([0.03695211, 0.00827317, 0.05959566, 0.04329074, 0.03455513,
#        0.00787046, 0.00609061, 0.01401238, 0.00873087, 0.00839336,
#        0.00997224, 0.00529675, 0.01122354, 0.00924915, 0.00490582,
#        0.00901208, 0.00960461, 0.00970497, 0.00918962, 0.31362607,
#        0.04335429, 0.13416556, 0.01854647, 0.00828912, 0.0417154 ,
#        0.02212856, 0.07734174, 0.00098514, 0.        , 0.00061167,
#        0.00481534, 0.01323385, 0.01526353])

# %%
importance_values=(selection.feature_importances_)*100

# %%
importance_values
# Out:
# array([ 3.69521115,  0.82731682,  5.95956606,  4.32907417,  3.45551276,
#         0.78704616,  0.60906065,  1.40123826,  0.87308692,  0.83933591,
#         0.99722369,  0.52967491,  1.12235405,  0.92491489,  0.49058195,
#         0.90120821,  0.96046078,  0.97049667,  0.91896199, 31.36260682,
#         4.33542877, 13.41655638,  1.85464736,  0.82891166,  4.17153973,
#         2.21285588,  7.73417433,  0.0985141 ,  0.        ,  0.06116673,
#         0.48153381,  1.32338509,  1.52635335])

# %%
columns_data_imp=X_train.columns

# %%
importance_data=pd.DataFrame({"columns_data_imp":columns_data_imp,"importance_values":importance_values})
importance_data
# Out:
#               columns_data_imp  importance_values
# 0                    loan_amnt           3.695211
# 1                         term           0.827317
# 2                     int_rate           5.959566
# 3                  installment           4.329074
# 4                        grade           3.455513
# 5                   emp_length           0.787046
# 6               home_ownership           0.609061
# 7                   annual_inc           1.401238
# 8          verification_status           0.873087
# 9                      purpose           0.839336
# 10                         dti           0.997224
# 11                 delinq_2yrs           0.529675
# 12              inq_last_6mths           1.122354
# 13                    open_acc           0.924915
# 14                     pub_rec           0.490582
# 15                   revol_bal           0.901208
# 16                  revol_util           0.960461
# 17                   total_acc           0.970497
# ...

# %%
sorted_importance= importance_data.sort_values(by='importance_values',ascending=False)
sorted_importance
# Out:
#               columns_data_imp  importance_values
# 19                   out_prncp          31.362607
# 21             total_rec_prncp          13.416556
# 26             last_pymnt_amnt           7.734174
# 2                     int_rate           5.959566
# 20                 total_pymnt           4.335429
# 3                  installment           4.329074
# 24                  recoveries           4.171540
# 0                    loan_amnt           3.695211
# 4                        grade           3.455513
# 25     collection_recovery_fee           2.212856
# 22               total_rec_int           1.854647
# 32            total_rev_hi_lim           1.526353
# 7                   annual_inc           1.401238
# 31                 tot_cur_bal           1.323385
# 12              inq_last_6mths           1.122354
# 10                         dti           0.997224
# 17                   total_acc           0.970497
# 16                  revol_util           0.960461
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scaler.transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (77937, 33)

# %%
from sklearn.linear_model import LogisticRegression
logistic_classifier= LogisticRegression()
logistic_classifier.fit(X_train,Y_train)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_pred = logistic_classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
cfm = confusion_matrix(Y_test, Y_pred)
print(cfm)
# Out:
# [[14642    44]
#  [   62   249]]

# %%
acc= accuracy_score(Y_test, Y_pred)

# %%
acc
# Out:
# 0.9929319197172768

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     14686
#            1       0.85      0.80      0.82       311
#
#     accuracy                           0.99     14997
#    macro avg       0.92      0.90      0.91     14997
# weighted avg       0.99      0.99      0.99     14997

# %%
p = sns.heatmap(pd.DataFrame(cfm), annot=True, cmap="magma" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
from sklearn.metrics import roc_curve
y_pred_proba = logistic_classifier.predict_proba(X_test)[:,1]
y_pred_proba
# Out:
# array([5.21350369e-02, 6.57038541e-02, 2.96474943e-04, ...,
#        9.99949527e-01, 9.99358606e-01, 1.00000000e+00])

# %%
from sklearn.metrics import roc_auc_score
legend_data=roc_auc_score(Y_test,y_pred_proba)
legend_data=round(legend_data,4)
legend_data
# Out:
# 0.9345

# %%
fpr, tpr, thresholds = roc_curve(Y_test, y_pred_proba)
print('FPR')
print(fpr)
print('TPR')
print(tpr)
print('Thresholds')
print(thresholds)
# Out:
# FPR
# [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 6.80920605e-05
#  6.80920605e-05 1.36184121e-04 1.36184121e-04 2.04276181e-04
#  2.04276181e-04 2.72368242e-04 2.72368242e-04 3.40460302e-04
#  3.40460302e-04 4.08552363e-04 4.08552363e-04 4.76644423e-04
#  4.76644423e-04 5.44736484e-04 5.44736484e-04 1.56611739e-03
#  1.56611739e-03 5.51545690e-03 5.65164102e-03 9.19242816e-03
#  9.19242816e-03 1.13713741e-02 1.15075582e-02 1.17118344e-02
#  1.17118344e-02 1.23927550e-02 1.25289391e-02 1.72953834e-02
#  1.74315675e-02 1.74315675e-02 2.24022879e-02 2.25384720e-02
#  2.73730083e-02 2.73730083e-02 2.74411004e-02 2.75772845e-02
#  2.81220210e-02 2.82582051e-02 3.07776113e-02 3.09137955e-02
#  3.40460302e-02 3.41822144e-02 3.62249762e-02 3.63611603e-02
#  3.69739888e-02 3.72463571e-02 3.73825412e-02 3.73825412e-02
#  3.79953697e-02 3.82677380e-02 4.11956966e-02 4.13318807e-02
# ...

# %%
plt.style.use('ggplot')
plt.plot(fpr,tpr, label='logistic regression',color='orange')
plt.plot([0,1],[0,1],'k--',color='navy')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title(' ROC curve')
plt.legend(["AUC=0.9345"], loc ="lower right") 
plt.show()

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(logistic_classifier, X_train, Y_train, cv=10, scoring = "accuracy")
print("Scores:", scores)
print("Mean:", scores.mean())
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# balanced_weight_classifier=LogisticRegression(class_weight='balanced')

# %%
# balanced_weight_classifier.fit(X_train,Y_train)

# %%
# Y_pred_weight=balanced_weight_classifier.predict(X_test)

# %%
# cfm = confusion_matrix(Y_test, Y_pred)
# print(cfm)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
Y_pred_Knn=knn.predict(X_test)

# %%
knn_cfm = confusion_matrix(Y_test, Y_pred_Knn)

# %%
knn_cfm
# Out:
# array([[13052,  1634],
#        [   62,   249]], dtype=int64)

# %%
accuracy_score(Y_test, Y_pred_Knn)
# Out:
# 0.8869107154764286

# %%
print(classification_report(Y_test,Y_pred_Knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94     14686
#            1       0.13      0.80      0.23       311
#
#     accuracy                           0.89     14997
#    macro avg       0.56      0.84      0.58     14997
# weighted avg       0.98      0.89      0.92     14997

# %%
p = sns.heatmap(pd.DataFrame(knn_cfm), annot=True, cmap="magma" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
y_pred_proba_knn = knn.predict_proba(X_test)[:,1]
y_pred_proba_knn
# Out:
# array([0.4, 0. , 0. , ..., 0.4, 0.6, 1. ])

# %%
legend_data_knn=roc_auc_score(Y_test,y_pred_proba_knn)
legend_data_knn=round(legend_data_knn,4)
legend_data_knn
# Out:
# 0.8883

# %%
fpr_knn, tpr_knn, thresholds_knn = roc_curve(Y_test, y_pred_proba_knn)

# %%
plt.style.use('ggplot')
plt.plot(fpr_knn,tpr_knn, label='KNN ',color='orange')
plt.plot([0,1],[0,1],'k--',color='navy')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title(' ROC curve')
plt.legend(["AUC=0.8883"], loc ="lower right") 
plt.show()
